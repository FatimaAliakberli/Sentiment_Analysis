# %% [markdown]
# # Downloading related libraries

# %%
pip install jpype1
# Out:
# Requirement already satisfied: jpype1 in /usr/local/lib/python3.12/dist-packages (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from jpype1) (25.0)

# %%
import pandas as pd
import numpy as np

# For NLP libraries
import nltk
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
import string
import re

# Zemberek setup
import jpype
from jpype import JClass, JString, getDefaultJVMPath, shutdownJVM, startJVM

# %%
ZEMBEREK_PATH = 'algorithm/zemberek-full.jar'

# %%
try:
    # Check if JVM is already started to avoid errors
    if not jpype.isJVMStarted():
        startJVM(getDefaultJVMPath(), '-ea', classpath=ZEMBEREK_PATH)

    # Initialize Zemberek Morphology
    TurkishMorphology = JClass('zemberek.morphology.TurkishMorphology')
    morphology = TurkishMorphology.createWithDefaults()
    print("Zemberek JVM started and Morphology initialized.")
except JVMException as e:
    print(f"Error starting JVM/Zemberek: {e}")
    print("Please ensure ZEMBEREK_PATH is correct and Java JDK is installed.")
# Out:
# Zemberek JVM started and Morphology initialized.

# %% [markdown]
# # Loading Data

# %%
review = pd.read_csv("data/e-ticaret_urun_yorumlari.csv", delimiter = ';')

# %%
review.columns = ['Comment', 'Sentiment']

# %%
review.head()
# Out:
#                                              Comment  Sentiment
# 0                              evet anlatıldığı gibi          1
# 1  Daha öncede almıştım bu cihazdan ense ve sakal...          1
# 2  Ürün gayet başarılı sakal kesmede başlık sayıs...          1
# 3  Daha öncede aynısını almıştım çok güzel ve kal...          1
# 4  Erkek kuaförüyüm ense ve sıfır sakal traşı içi...          1

# %%
def character_switch(text):
    text = text.lower()
    text = text.replace('ç', 'c')
    text = text.replace('ğ', 'g')
    text = text.replace('ü', 'u')
    text = text.replace('ö', 'o')
    text = text.replace('ş', 's')
    text = text.replace('ı', 'i')

    return text



review['comment_english'] = review['Comment'].apply(character_switch)

# %%
review.head()
# Out:
#                                              Comment  Sentiment  \
# 0                              evet anlatıldığı gibi          1
# 1  Daha öncede almıştım bu cihazdan ense ve sakal...          1
# 2  Ürün gayet başarılı sakal kesmede başlık sayıs...          1
# 3  Daha öncede aynısını almıştım çok güzel ve kal...          1
# 4  Erkek kuaförüyüm ense ve sıfır sakal traşı içi...          1
#
#                                      comment_english
# 0                              evet anlatildigi gibi
# 1  daha oncede almistim bu cihazdan ense ve sakal...
# 2  urun gayet basarili sakal kesmede baslik sayis...
# 3  daha oncede aynisini almistim cok guzel ve kal...
# 4  erkek kuaforuyum ense ve sifir sakal trasi ici...

# %% [markdown]
# # Removing Stop words

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Load Turkish Stopwords and extend with punctuation
stop_words = stopwords.words('turkish')
# Add punctuation marks to the list
stop_words.extend(list(string.punctuation))

print(f"Number of Turkish stopwords: {len(stopwords.words('turkish'))}")
# Out:
# Number of Turkish stopwords: 53

# %% [markdown]
# We firstly wanted to use stopwords from nltk library. However, their result was 53 words, which seems to low. So we decided to use custom dataset from kaggle for this purpose.

# %%
custom_stopwords = pd.read_json("custom/turkce_stopwords.json")

# %%
print("Stopwords DataFrame Shape:", custom_stopwords.shape)
print("\nFirst 5 Stopwords (Check Column Name/Structure):")
print(custom_stopwords.head(5))
# Out:
# Stopwords DataFrame Shape: (504, 1)
#
# First 5 Stopwords (Check Column Name/Structure):
#     stopwords
# 0           a
# 1       acaba
# 2        acep
# 3  adamakıllı
# 4       adeta

# %% [markdown]
# Here more words are aviable, which is good.

# %%
turkish_stopwords_set = set(custom_stopwords['stopwords'].str.lower())

# %% [markdown]
# Later we use TweetTokenizer. We will split each word in our dataset and see if they are aviable in stopwords or not. While we are splitting, we approach each word, including punctuation mark seperately. However, there are some emojis, that we don't want them to get seperated, such as :), :(, :)), they have a meaning in our dataset, such as :) positive, :( negative and so on. Considering all these, we used TweetTokenizer.

# %%
tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)

# %%
def remove_stopwords(dataset, stopwords_set):
  cleaned_data = []
  for text in dataset:
    tokens = tokenizer.tokenize(text.lower())
    filtered_tokens = [word for word in tokens if word not in stopwords_set]
    cleaned_data.append(" ".join(filtered_tokens))

  return cleaned_data

# %%
review["comment_english"] = remove_stopwords(review["comment_english"], turkish_stopwords_set)
review["copy_comment"] = remove_stopwords(review["Comment"], turkish_stopwords_set)

# %% [markdown]
# Example row from dataset. There is a word like "amma", but after removing stop words, we will remove "amma" from here

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


print(review.loc[[310], ["Comment", "comment_english"]])
print(review.loc[[310], ["Comment", "copy_comment"]])
# Out:
#                                                                                                               Comment  \
# 310  ürünü begendim Amma taraklar hariç...sadece kısa kesim yapacaklar için uygun.saç kesiminde de performansı iyi...
#
#                                                                                       comment_english
# 310  urunu begendim taraklar haric ... kisa kesim yapacaklar icin uygun.sac kesiminde performansi ...
#                                                                                                               Comment  \
# 310  ürünü begendim Amma taraklar hariç...sadece kısa kesim yapacaklar için uygun.saç kesiminde de performansı iyi...
#
#                                                                                 copy_comment
# 310  ürünü begendim taraklar ... kısa kesim yapacaklar uygun . saç kesiminde performansı ...

# %% [markdown]
# ### Checking emojis are there or not

# %%
emoji_pattern_ascii = r'[:;=]-?[)D(P]'

emoji_reviews = review[
    review["comment_english"].str.contains(emoji_pattern_ascii, regex=True, na=False)
]

print(f"\n--- Reviews with ASCII Emoticons ({len(emoji_reviews)} found) ---")
print(emoji_reviews[["Comment", "comment_english"]].head())
# Out:
# --- Reviews with ASCII Emoticons (301 found) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Comment  \
# 192                                                                                                                                                                                                                                                                                                                                                  Motoru güçlü. Kesimi çok iyi çekme yok. Hassas bölgelerde kullanırken dikkatli olmak lazım :) iki eksiği var bana göre: başlıkları çok kötü. Ben 3 mm kullanırım kısaltırım diye umuyordum ama kullanamadım. Başlığı takınca kesmedi sakalları birazını alıyor birazını bırakıyor falan. Kısacası başlık performansı kötü. Diğer sorun da parlak yüzeyler. Hem çok kaygan hem de kıl tutuyor çok fazla.
# 683                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Ürün kaliteli anlatıldığı gibi indirimli fiyatı ile aldım kaçırılmayacak bir cihaz gönül rahatlığıyla düşünmeden alabilirsiniz pahalanmadan n11 mağazadan siparisiniz verin kargo hızlı bir şekilde geldi teşekkürler n11 :)
# 685                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Ürün gerçekten iyi bu fiyata değer berberden hesaplı mantıklı berbere gitmeye son :)))
# 715  Soru cevap bölümünde sorulan soruları olumsuz tepkilerden dolayı sürekli olarak silen mağaza bu yorumumu silemeyecek bu sefer :).Üründe tarak çeşitliliği olsaydı daha iyi olurdu ancak zaten bunu bilerek almıştım.Ürün, iyi kullanışlı bir ürün.Gelelim mağazaya; mağaza her müşterisinin her farklı sorusuna kopyala yapıştır aynı cevabi veriyor.Diyelim ki Mağazaya "nasılsınız?" diye soru sordunuz yine aynı kopyala yapıştır cevabı verir mağaza.Bir çok musteri soru cevap bölümünde problem yaşamakta okursanız görürsünüz,tabi mağaza silmediyse :).Virüs nedeniyle zor zamanlardan geçiyoruz bunu anlıyorum gecikmeler tabiki yaşanır bunu da anlıyorum ama, işimizi iyi yapmamız gerekiyor.Magazanin biraz daha dikkatli olması gerekiyor.
# 742                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Kesinlikle bu mağazayı tavsiye etmiyorum. Defolu ürün gönderiyorlar. Tüketici hakem heyetine başvurdum ürün tutarı az da olsa hakkımı arayacağım siz de sonuna kadar arayın parası az demeyin. Haklıysanız elbet lehinize karar çıkacaktır :))
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             comment_english
# 192                                                                                                                                                                                                                                                                                              motoru guclu . kesimi cok cekme . hassas bolgelerde kullanirken dikkatli lazim :) eksigi gore : basliklari cok kotu . 3 mm kullanirim kisaltirim umuyordum kullanamadim . basligi takinca kesmedi sakallari birazini aliyor birazini birakiyor falan . kisacasi baslik performansi kotu . diger sorun parlak yuzeyler . cok kaygan kil tutuyor cok fazla .
# 683                                                                                                                                                                                                                                                                                                                                                                                                                                             urun kaliteli anlatildigi indirimli fiyati aldim kacirilmayacak cihaz gonul rahatligiyla dusunmeden alabilirsiniz pahalanmadan n11 magazadan siparisiniz verin kargo hizli sekilde geldi tesekkurler n11 :)
# 685                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       urun gercekten fiyata deger berberden hesapli mantikli berbere gitmeye son :) ) )
# 715  soru cevap bolumunde sorulan sorulari olumsuz tepkilerden dolayi surekli silen magaza yorumumu silemeyecek sefer :) . urunde tarak cesitliligi olsaydi olurdu bilerek almistim.urun , kullanisli urun.gelelim magazaya ; magaza musterisinin farkli sorusuna kopyala yapistir ayni cevabi veriyor.diyelim magazaya " nasilsiniz ? " soru sordunuz ayni kopyala yapistir cevabi verir magaza.bir cok musteri soru cevap bolumunde problem yasamakta okursaniz gorursunuz , tabi magaza silmediyse :) . virus zor zamanlardan geciyoruz anliyorum gecikmeler tabiki yasanir anliyorum , isimizi yapmamiz gerekiyor.magazanin dikkatli olmasi gerekiyor .
# 742                                                                                                                                                                                                                                                                                                                                                                                                                                          kesinlikle magazayi tavsiye etmiyorum . defolu urun gonderiyorlar . tuketici hakem heyetine basvurdum urun tutari hakkimi arayacagim sonuna arayin parasi demeyin . hakliysaniz lehinize karar cikacaktir :) )

# %% [markdown]
# # Preprocessing Data

# %% [markdown]
# ## STREM and FPS (Fixed Prefix Stemmer)

# %%
punctuation = set(string.punctuation)

# %%
def preprocess_turkish_text(dataset, stopwords_set, stemming_method='none', prefix_length=None):
    """
    Applies Tokenization, Stopword Removal (STREM), and Fixed Prefix Stemming (FPS).
    """
    cleaned_data = []
    for text in dataset:
        if not text:
            cleaned_data.append("")
            continue
        tokens = tokenizer.tokenize(text.lower())
        filtered_tokens = []
        for word in tokens:
            is_stopword = word in stopwords_set
            is_punctuation = word in punctuation

            if not is_stopword and not is_punctuation:
                if stemming_method == 'fps' and prefix_length is not None:
                    # FPS: Take the first 'n' characters of the word
                    stemmed_word = word[:prefix_length]
                    filtered_tokens.append(stemmed_word)
                elif stemming_method == 'none':
                    # STREM Only
                    filtered_tokens.append(word)
        cleaned_data.append(" ".join(filtered_tokens))
    return pd.Series(cleaned_data, index=dataset.index)

# %%
review["STREM+FPS3"] = preprocess_turkish_text(review["comment_english"], turkish_stopwords_set, stemming_method='fps', prefix_length=3)
review["STREM+FPS5"] = preprocess_turkish_text(review["comment_english"], turkish_stopwords_set, stemming_method='fps', prefix_length=5)
review["STREM+FPS7"] = preprocess_turkish_text(review["comment_english"], turkish_stopwords_set, stemming_method='fps', prefix_length=7)

# %%
# Set display options to see full text
pd.set_option('display.max_colwidth', None)

# Select the original column and all new processed columns
comparison_columns = [
    "comment_english",
    "STREM+FPS3",
    "STREM+FPS5",
    "STREM+FPS7",
]

# Display the comparison for a sample row (like 312)
print("--- Comparison of Turkish Preprocessing Methods (Row 312) ---")
print(review.loc[[312], comparison_columns].T)
# Out:
# --- Comparison of Turkish Preprocessing Methods (Row 312) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                  312
# comment_english  urun guzel uzun zamandir takip ettigim urun kargo hizli parcalar eksik fabrikadan son paketleyen yada gelene ustune nikelajinda yuzunde darbeler tane diyecem 7-8 adet darbe cizik kullandikca komple nikelaji atmazsa iyidir bakalim kesimi nasil denemedim henuz paketi yeni actim firma yetkililerine selamlar dikkate alirsiniz umarim kalite kontrol yada paketlemeden once son bi urunlere bakarsaniz sagina soluna jelatin yaparsaniz cihaza
# STREM+FPS3                                                                                                                                                                                                                uru guz uzu zam tak ett uru kar hiz par eks fab son pak yad gel ust nik yuz dar tan diy 7-8 ade dar ciz kul kom nik atm iyi bak kes nas den hen pak yen act fir yet sel dik ali uma kal kon yad pak onc son bi uru bak sag sol jel yap cih
# STREM+FPS5                                                                                                           urun guzel uzun zaman takip ettig urun kargo hizli parca eksik fabri son paket yada gelen ustun nikel yuzun darbe tane diyec 7-8 adet darbe cizik kulla kompl nikel atmaz iyidi bakal kesim nasil denem henuz paket yeni actim firma yetki selam dikka alirs umari kalit kontr yada paket once son bi urunl bakar sagin solun jelat yapar cihaz
# STREM+FPS7                                                urun guzel uzun zamandi takip ettigim urun kargo hizli parcala eksik fabrika son paketle yada gelene ustune nikelaj yuzunde darbele tane diyecem 7-8 adet darbe cizik kulland komple nikelaj atmazsa iyidir bakalim kesimi nasil denemed henuz paketi yeni actim firma yetkili selamla dikkate alirsin umarim kalite kontrol yada paketle once son bi urunler bakarsa sagina soluna jelatin yaparsa cihaza

# %% [markdown]
# These models are all good, but not ideal, as STREM do not consider finding root, and FPS algorithms just choose first 3, 5 and 7 letters without actually considering for meaning.

# %% [markdown]
# ## Zemberek algorithm

# %% [markdown]
# Zemberek is an open-source NLP library specifically developed for the Turkish language. Written in Java, it is designed to handle the structural challenges of Turkish. It can perform tasks such as morphological analysis, grammar checking, sentence parsing, and many more operations on Turkish texts.

# %%
def zemberek_stem(word, morphology_instance):
    """
    Zemberek'in en güvenilir analiz metoduyla (analyzeAndDisambiguate) lema bulma.
    """
    try:
        # Python dizesini açıkça Java dizesine dönüştür
        java_word = JString(word)

        # 1. Analiz et ve anlam karmaşasını çöz
        analysis_result = morphology_instance.analyzeAndDisambiguate(java_word)
        best_analysis_list = analysis_result.bestAnalysis()

        if best_analysis_list and best_analysis_list.size() > 0:
            # En iyi analizi al
            best_analysis = best_analysis_list.get(0)

            # **KÖK/LEMA BULMA KRİTİK ADIM**
            # Analizin Lemmalar listesini al ve ilkini (en temelini) kullan.
            lemmas = best_analysis.getLemmas()

            if lemmas.size() > 0:
                # Java listesinden lemayı al ve Python dizesine dönüştür
                lemma = str(lemmas.get(0))

                # 'UNK' (Bilinmiyor) kontrolü (Gerekirse)
                if lemma != 'UNK':
                    return lemma

        # Analiz başarısız olursa veya lemma 'UNK' ise orijinal kelimeyi döndür.
        return word
    except Exception as e:
        # Hata ayıklama için print(f"Zemberek Hata: {word} -> {e}")
        return word

# %%
def preprocess_turkish_text_with_zemberek(dataset, stopwords_set, morphology_instance):
    """
    Geliştirilmiş Zemberek kök bulma mantığı ile metin ön işleme.
    """
    # TweetTokenizer ve stopword/noktalama filtreleme mantığı aynı kalır.
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
    punctuation = set(string.punctuation)
    cleaned_data = []

    for text in dataset:
        if not isinstance(text, str) or not text.strip():
            cleaned_data.append("")
            continue

        tokens = tokenizer.tokenize(text.lower())

        filtered_tokens = []
        for word in tokens:
            is_stopword = word in stopwords_set
            is_punctuation = word in punctuation

            if not is_stopword and not is_punctuation:

                if word.isalpha():
                    # YENİ ve GÜVENİLİR kök bulma fonksiyonunu çağır
                    stemmed_word = zemberek_stem(word, morphology_instance)
                    filtered_tokens.append(stemmed_word)
                else:
                    # Emoticon, sayı, vs. olduğu gibi bırakılır.
                    filtered_tokens.append(word)

        cleaned_data.append(" ".join(filtered_tokens))

    return pd.Series(cleaned_data, index=dataset.index)

# %%
from jpype import JString
from typing import List

# %%
# Lütfen bu kodu çalıştırmadan önce, yukarıdaki fonksiyonları tanımladığınızdan emin olun.

def verify_zemberek_stemming(words: List[str], morphology_instance):
    results = []

    for word in words:
        # zemberek_stem_final'ı çağır
        stemmed_word = zemberek_stem(word.lower(), morphology_instance)

        results.append({
            "Original Word": word,
            "Stemmed Word (ZEM)": stemmed_word
        })

    return pd.DataFrame(results)

test_words = [
    "Gelmek",        # Infinitive
    "Geliyorum",     # I am coming
    "Geldiler",      # They came
    "Gelmiştik",     # We had come
    "Geleceksin",    # You will come
    "ürünlerimizin", # Noun inflection
    "başarılı",      # Adjective
    "almıştım",
    "almistim",
]

verification_df = verify_zemberek_stemming(test_words, morphology)

print("--- Zemberek Stemming Verification Test (Final Attempt) ---")
print(verification_df)
# Out:
# --- Zemberek Stemming Verification Test (Final Attempt) ---
#    Original Word Stemmed Word (ZEM)
# 0         Gelmek                gel
# 1      Geliyorum                gel
# 2       Geldiler                gel
# 3      Gelmiştik                gel
# 4     Geleceksin                gel
# 5  ürünlerimizin               ürün
# 6       başarılı             başarı
# 7       almıştım                 al
# 8       almistim           almistim

# %% [markdown]
# Here we can see that Zemberek algorithm succesfully found the root of the words. Also, we observe that some words, such as almıştım, are recognized and their root is extracted succesfully, compared to when their letters are switched to English alphabet, as almistim. Therefore, we will refer to original dataset with only stopwords removed version to get better results in root finding.

# %%
review["STREM+ZEM"] = preprocess_turkish_text_with_zemberek(
    review["copy_comment"],
    turkish_stopwords_set,
    morphology # <--- The initialized Zemberek object from your setup
)

# %%
# Set display options to see full text
pd.set_option('display.max_colwidth', None)

# Select the original column and all new processed columns
comparison_columns = [
    "comment_english",
    "copy_comment",
    "STREM+FPS3",
    "STREM+FPS5",
    "STREM+FPS7",
    "STREM+ZEM" # Placeholder
]

# Display the comparison for a sample row (like 312)
print("--- Comparison of Turkish Preprocessing Methods (Row 312) ---")
print(review.loc[[312], comparison_columns].T)
# Out:
# --- Comparison of Turkish Preprocessing Methods (Row 312) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                  312
# comment_english  urun guzel uzun zamandir takip ettigim urun kargo hizli parcalar eksik fabrikadan son paketleyen yada gelene ustune nikelajinda yuzunde darbeler tane diyecem 7-8 adet darbe cizik kullandikca komple nikelaji atmazsa iyidir bakalim kesimi nasil denemedim henuz paketi yeni actim firma yetkililerine selamlar dikkate alirsiniz umarim kalite kontrol yada paketlemeden once son bi urunlere bakarsaniz sagina soluna jelatin yaparsaniz cihaza
# copy_comment                   ürün güzel uzun zamandır takip ettiğim ürün kargo hızlı parçalar eksik fabrikadan son paketleyen yada gelene üstüne nikelajında ön yüzünde darbeler tane diyecem 7-8 adet darbe çizik kullandıkça komple nikelajı atmazsa iyidir bakalım kesimi denemedim paketi yeni açtım firma yetkililerine selamlar dikkate alırsınız umarım kalite kontrol yada paketlemeden son bi ürünlere bakarsanız sağına soluna jelatın yaparsanız cihaza
# STREM+FPS3                                                                                                                                                                                                                uru guz uzu zam tak ett uru kar hiz par eks fab son pak yad gel ust nik yuz dar tan diy 7-8 ade dar ciz kul kom nik atm iyi bak kes nas den hen pak yen act fir yet sel dik ali uma kal kon yad pak onc son bi uru bak sag sol jel yap cih
# STREM+FPS5                                                                                                           urun guzel uzun zaman takip ettig urun kargo hizli parca eksik fabri son paket yada gelen ustun nikel yuzun darbe tane diyec 7-8 adet darbe cizik kulla kompl nikel atmaz iyidi bakal kesim nasil denem henuz paket yeni actim firma yetki selam dikka alirs umari kalit kontr yada paket once son bi urunl bakar sagin solun jelat yapar cihaz
# STREM+FPS7                                                urun guzel uzun zamandi takip ettigim urun kargo hizli parcala eksik fabrika son paketle yada gelene ustune nikelaj yuzunde darbele tane diyecem 7-8 adet darbe cizik kulland komple nikelaj atmazsa iyidir bakalim kesimi nasil denemed henuz paketi yeni actim firma yetkili selamla dikkate alirsin umarim kalite kontrol yada paketle once son bi urunler bakarsa sagina soluna jelatin yaparsa cihaza
# STREM+ZEM                                                                                                                                           ürün güzel uzun zaman takip et ürün kargo hız parça eksik fabrika son paketle yad gel üst nikelaj ön yüz darbe tane diyecem 7-8 adet darbe çizik kullan komple nikelaj at iyi bak kesim dene paket yeni aç firma yetkili selam dikkat al um kalite kontrol yad paketle son bi ürün bak sağ sol jelatın yap cihaz

# %%
from collections import defaultdict

def calculate_text_statistics(text_series):
    """Calculates the total dictionary size and average document length."""

    term_counts = defaultdict(int)
    doc_lengths = []

    for text in text_series:
        if not text:
            doc_lengths.append(0)
            continue

        words = text.split()
        doc_lengths.append(len(words))

        # Count term frequencies for dictionary size
        for word in words:
            term_counts[word] += 1

    total_unique_terms = len(term_counts)
    total_documents = len(text_series)
    avg_terms_per_document = sum(doc_lengths) / total_documents if total_documents else 0

    return {
        "N_terms": total_unique_terms,
        "Avg_terms_per_document": avg_terms_per_document,
    }

# --- Calculation ---
results = {}

# List of columns to analyze (including the original Metin for baseline)
preprocessing_columns = [
    "copy_comment",
    "STREM+FPS3",
    "STREM+FPS5",
    "STREM+FPS7",
    "STREM+ZEM" # Placeholder
]

# Calculate statistics for each column
for col in preprocessing_columns:
    if col in review.columns:
        results[col] = calculate_text_statistics(review[col])
    elif col == "copy_comment":
        # Calculate original data (no preprocessing)
        results["copy_comment (None)"] = calculate_text_statistics(review[col].astype(str).str.lower())
    elif col == "STREM+ZEM":
        # Placeholder for Zemberek, based on Milliyet_9c_1k corpus statistics
        # This gives a realistic target for Zemberek's effectiveness.
        results["STREM+ZEM (Target)"] = {
            "N_terms": "Approx. 17,000",
            "Avg_terms_per_document": "Approx. 225",
        }

# Convert results dictionary to a DataFrame for clean display
comparison_df = pd.DataFrame(results).T

print("\n--- Numerical Comparison of Preprocessing Methods ---")
print(comparison_df)
# Out:
# --- Numerical Comparison of Preprocessing Methods ---
#               N_terms  Avg_terms_per_document
# copy_comment  19331.0                9.930587
# STREM+FPS3     1960.0                9.885761
# STREM+FPS5     6451.0                9.885893
# STREM+FPS7    11842.0                9.885893
# STREM+ZEM      9451.0                8.953790

# %% [markdown]
# ### Checking for emojis in STREM+ZEM column

# %%
emoji_pattern_ascii = r'[:;=]-?[)D(P]'

emoji_reviews = review[
    review["STREM+ZEM"].str.contains(emoji_pattern_ascii, regex=True, na=False)
]

print(f"\n--- Reviews with ASCII Emoticons ({len(emoji_reviews)} found) ---")
print(emoji_reviews[["copy_comment", "STREM+ZEM"]].head())
# Out:
# --- Reviews with ASCII Emoticons (301 found) ---
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                copy_comment  \
# 192                                                                                                                                                                                                                                                                                                         motoru güçlü . kesimi çekme . hassas bölgelerde kullanırken dikkatli lazım :) eksiği : başlıkları kötü . 3 mm kullanırım kısaltırım umuyordum kullanamadım . başlığı takınca kesmedi sakalları birazını alıyor birazını bırakıyor falan . kısacası başlık performansı kötü . sorun parlak yüzeyler . kaygan kıl tutuyor fazla .
# 683                                                                                                                                                                                                                                                                                                                                                                                                                             ürün kaliteli anlatıldığı indirimli fiyatı aldım kaçırılmayacak cihaz gönül rahatlığıyla düşünmeden alabilirsiniz pahalanmadan n11 mağazadan siparisiniz verin kargo hızlı şekilde geldi teşekkürler n11 :)
# 685                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ürün gerçekten fiyata değer berberden hesaplı mantıklı berbere gitmeye son :) ) )
# 715  soru cevap bölümünde sorulan soruları olumsuz tepkilerden sürekli silen mağaza yorumumu silemeyecek sefer :) . üründe tarak çeşitliliği olsaydı olurdu bilerek almıştım . ürün , kullanışlı ürün . gelelim mağazaya ; mağaza müşterisinin farklı sorusuna kopyala yapıştır aynı cevabi veriyor.diyelim mağazaya " nasılsınız ? " soru sordunuz aynı kopyala yapıştır cevabı verir mağaza . musteri soru cevap bölümünde problem yaşamakta okursanız görürsünüz , tabi mağaza silmediyse :) . virüs zor zamanlardan geçiyoruz anlıyorum gecikmeler tabiki yaşanır anlıyorum , işimizi yapmamız gerekiyor.magazanin dikkatli gerekiyor .
# 742                                                                                                                                                                                                                                                                                                                                                                                                                          kesinlikle mağazayı tavsiye etmiyorum . defolu ürün gönderiyorlar . tüketici hakem heyetine başvurdum ürün tutarı hakkımı arayacağım sonuna arayın parası demeyin . haklıysanız lehinize karar çıkacaktır :) )
#
#                                                                                                                                                                                                                                                                                                                                                                                                                       STREM+ZEM
# 192                                                                                                                                                                                               motor güç kesim çek hassas bölge kullan dikkat lazım :) eksik başlık kötü 3 mm kullan kısal um kullan başlık tak kes sakal biraz al biraz bırak falan kısacası başlık performans kötü sorun parlak yüzey kaygan kıl tut fazla
# 683                                                                                                                                                                                                                                                                                   ürün kalite anla indirim fiyat al kaçır cihaz gönül rahat düşün al pahalan n11 mağaza siparisiniz ver kargo hız şekil gel teşekkür n11 :)
# 685                                                                                                                                                                                                                                                                                                                                                            ürün gerçekten fiyat değer berber hesap mantık berber git son :)
# 715  soru cevap bölüm soru soru olumsuz tepki sürekli sil mağaza yorum sil sefer :) ürün tarak çeşit ol ol bil al ürün kullan ürün gel mağaza mağaza müşteri fark soru kopyala yap aynı cevabi veriyor.diyelim mağaza nasıl soru sor aynı kopyala yap cevap ver mağaza musteri soru cevap bölüm problem yaşa oku gör tabi mağaza sil :) virüs zor zaman geç anla gecik tabiki yaşa anla iş yap gerekiyor.magazanin dikkat gerek
# 742                                                                                                                                                                                                                                                                                              kesinlikle mağaza tavsiye et defo ürün gönder tüket hakem heyet başvur ürün tutar hak ara son ara para de hak leh karar çık :)

# %% [markdown]
# # Saving Preprocessed Dataset

# %%
review.to_csv("preprocessed_reviews.csv", index=False, encoding='utf-8')

# %%
files.download("data/preprocessed_reviews.csv")
